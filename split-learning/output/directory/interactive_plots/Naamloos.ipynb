# %%
import pickle
import matplotlib.pyplot as plt

# Enable interactive plots in Jupyter notebook
# %matplotlib inline

# Load the .fig.pkl file
file_path = 'batch_size_client_num_in_total.fig.pkl'

with open(file_path, 'rb') as f:
    fig = pickle.load(f)

# Display the interactive plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-033c85124d16> in <module>
#       9
#      10 with open(file_path, 'rb') as f:
# ---> 11     fig = pickle.load(f)
#      12
#      13 # Display the interactive plot
#
# ModuleNotFoundError: No module named 'matplotlib.axes._subplots'

# %%
# !pip install --upgrade matplotlib
# Out:
# Requirement already up-to-date: matplotlib in /Users/amradwan/opt/anaconda3/lib/python3.8/site-packages (3.7.1)
# ...

# %%
# !conda info --envs
# Out:
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "/Users/amradwan/opt/anaconda3/lib/python3.8/site-packages/conda/exceptions.py", line 1129, in __call__
#         return func(*args, **kwargs)
#       File "/Users/amradwan/opt/anaconda3/lib/python3.8/site-packages/conda/cli/main.py", line 86, in main_subshell
#         exit_code = do_call(args, p)
#       File "/Users/amradwan/opt/anaconda3/lib/python3.8/site-packages/conda/cli/conda_argparse.py", line 91, in do_call
#         module = import_module(relative_mod, __name__.rsplit('.', 1)[0])
#       File "/Users/amradwan/opt/anaconda3/lib/python3.8/importlib/__init__.py", line 127, in import_module
#         return _bootstrap._gcd_import(name[level:], package, level)
#       File "<frozen importlib._bootstrap>", line 1014, in _gcd_import
#       File "<frozen importlib._bootstrap>", line 991, in _find_and_load
# ...

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ab0680a89434> in <module>
# ----> 1 n
#
# NameError: name 'n' is not defined

# %%
import pickle
from IPython.display import Image

# Load the .fig.pkl file
file_path = 'batch_size_client_num_in_total.fig.pkl'

with open(file_path, 'rb') as f:
    fig = pickle.load(f)

# Save the figure as a PNG image
fig.savefig('batch_size_client_num_in_total.png')

# Display the PNG image in the notebook
Image(filename='batch_size_client_num_in_total.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-c3d230622f14> in <module>
#       6
#       7 with open(file_path, 'rb') as f:
# ----> 8     fig = pickle.load(f)
#       9
#      10 # Save the figure as a PNG image
#
# ModuleNotFoundError: No module named 'matplotlib.axes._subplots'

# %%
# !pip list
# Out:
# Package                                           Version
# ------------------------------------------------- --------------------
# aiohttp                                           3.8.4
# aiosignal                                         1.3.1
# alabaster                                         0.7.12
# anaconda-client                                   1.7.2
# anaconda-navigator                                1.10.0
# anaconda-project                                  0.8.3
# appdirs                                           1.4.4
# applaunchservices                                 0.2.1
# appnope                                           0.1.0
# appscript                                         1.1.1
# argh                                              0.26.2
# argon2-cffi                                       20.1.0
# asn1crypto                                        1.4.0
# astroid                                           2.4.2
# ...

# %%
# !conda info --envs
# Out:
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "/Users/amradwan/opt/anaconda3/lib/python3.8/site-packages/conda/exceptions.py", line 1129, in __call__
#         return func(*args, **kwargs)
#       File "/Users/amradwan/opt/anaconda3/lib/python3.8/site-packages/conda/cli/main.py", line 86, in main_subshell
#         exit_code = do_call(args, p)
#       File "/Users/amradwan/opt/anaconda3/lib/python3.8/site-packages/conda/cli/conda_argparse.py", line 91, in do_call
#         module = import_module(relative_mod, __name__.rsplit('.', 1)[0])
#       File "/Users/amradwan/opt/anaconda3/lib/python3.8/importlib/__init__.py", line 127, in import_module
#         return _bootstrap._gcd_import(name[level:], package, level)
#       File "<frozen importlib._bootstrap>", line 1014, in _gcd_import
#       File "<frozen importlib._bootstrap>", line 991, in _find_and_load
# ...
